# %%
from geotile import GeoTile

# %%
PATH_TEST_X = r'C:\Users\jabir\Project\UNet\data\Pidie_2022-06_test.tif'
PATH_TEST_Y = r'C:\Users\jabir\Project\UNet\data\1109_sawah_test.shp'

# %%
PATH_TRAIN_X = r'C:\Users\jabir\Project\UNet\data\Pidie_2022-06_train.tif'
PATH_TRAIN_Y = r'C:\Users\jabir\Project\UNet\data\1109_sawah_train.shp'

# %%
gt_train = GeoTile(PATH_TRAIN_X)
gt_train.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'float32',
#  'nodata': None,
#  'width': 2007,
#  'height': 2144,
#  'count': 3,
#  'crs': CRS.from_epsg(4326),
#  'transform': Affine(0.00036613514077670303, 0.0, 95.74337815246122,
#         0.0, -0.0003646272879999966, 5.439188035472024)}

# %%
gt_train.generate_tiles(r'C:\Users\jabir\Project\UNet\data\train', prefix='train_')

# %%
gt_train.rasterization(PATH_TRAIN_Y, r'C:\Users\jabir\Project\UNet\data\y_train.tif')
# Out:
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 0 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 2 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 3 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 4 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 5 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 6 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 7 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 8 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 9 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 10 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 11 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 12 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 13 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 14 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 16 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 17 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 18 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 19 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 20 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 21 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 22 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 23 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 25 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 26 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 27 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 28 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 29 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 30 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 31 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 32 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 33 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 34 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 35 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 36 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 37 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 38 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 39 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 40 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 41 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 42 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 43 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 44 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 45 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 46 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 47 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 48 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 49 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 50 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 51 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 52 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 53 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 54 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 55 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 56 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 57 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 58 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 59 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 60 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 61 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 62 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 63 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 64 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 65 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 66 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 67 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 68 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 69 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 70 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 71 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 72 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 73 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 74 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 109 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 110 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 111 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 112 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 113 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 114 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 115 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 116 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 117 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# c:\Users\jabir\anaconda3\envs\tf\lib\site-packages\rasterio\features.py:324: ShapeSkipWarning: Invalid or empty shape None at index 617 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)

# %%
gt_train_y = GeoTile('../UNet/data/y_train.tif')

# %%
gt_train_y.generate_tiles(r'C:\Users\jabir\Project\UNet\data\train_y', prefix='train_')

# %%
gt_test = GeoTile(PATH_TEST_X)

gt_test.generate_tiles('../UNet/data/test_x', prefix = 'test_x_')

gt_test.rasterization(PATH_TEST_Y, '../UNet/data/y_test.tif')

# %%
gt_test_y = GeoTile('../UNet/data/y_test.tif')
gt_test_y.generate_tiles('../UNet/data/test_y', prefix = 'test_y_')

# %%
# generate tiles and store it inside geotile package
gt_train.generate_tiles(save_tiles=False)
gt_train_y.generate_tiles(save_tiles=False)

# preprocessing (eg. convert nan to zero and normalization of tiles)
gt_train.convert_nan_to_zero()
# gt_train.normalize_tiles()

# save it as a numpy array
# gt_train.save_numpy('../../data/end_to_end_DL/X_train.npy')
# gt_train_y.save_numpy('../../data/end_to_end_DL/y_train.npy')

# %%
gt_train.normalize_tiles()

# %%
import numpy as np
gt_train.tile_data.min(), gt_train.tile_data.max()
# Out:
# (0.0, 1.0)

# %%
gt_train.save_numpy('../../Project/UNet/data/X_train.npy')
gt_train_y.save_numpy('../../Project/UNet/data/y_train.npy')

# %%
# generate tiles and store it inside geotile package
gt_test.generate_tiles(save_tiles=False)
gt_test_y.generate_tiles(save_tiles=False)

# preprocessing (eg. convert nan to zero and normalization of tiles)
gt_test.convert_nan_to_zero()
gt_test.normalize_tiles()

# save it as a numpy array
gt_test.save_numpy('../UNet/data/X_test.npy')
gt_test_y.save_numpy('../UNet/data/y_test.npy')

# %%
import numpy as np

X_train = np.load('../../Project/UNet/data/X_train.npy')
X_train.max(), X_train.min(), X_train.dtype, X_train.shape
# Out:
# (1.0, 0.0, dtype('float32'), (272, 256, 256, 3))

# %%
y_train= np.load('../../Project/UNet/data/y_train.npy')

# %%
import matplotlib.pyplot as plt

# Let's plot a sample input RGB image and output image with buildings
fig, (ax1, ax2) = plt.subplots(1,2)
img = np.random.randint(53,59)
print(img)
ax1.imshow(X_train[img, :, :, :3])
ax2.imshow(y_train[img, :, :, 0])
ax1.set_title("Image")
ax2.set_title('Mask')
plt.show()
# Out:
# 53

# %%
import numpy as np

X_test = np.load('../UNet/data/X_test.npy')
X_test.max(), X_test.min(), X_test.dtype, X_test.shape
# Out:
# (1.0, 0.0, dtype('float32'), (12, 256, 256, 3))

# %%
y_test= np.load('../UNet/data/y_test.npy')

# %%
import matplotlib.pyplot as plt

# Let's plot a sample input RGB image and output image with buildings
fig, (ax1, ax2) = plt.subplots(1,2)
img = np.random.randint(0, 12)
print(img)
ax1.imshow(X_test[img, :, :, :3])
ax2.imshow(y_test[img, :, :, 0])
ax1.set_title("Image")
ax2.set_title('Mask')
plt.show()
# Out:
# 6
