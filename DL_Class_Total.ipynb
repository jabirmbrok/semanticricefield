# %%
import pandas as pd
import numpy as np
import keras
from keras import Sequential
from keras.layers import Conv1D, MaxPooling1D, Dense, Dropout, Flatten, Input, GlobalMaxPooling1D
from keras.callbacks import EarlyStopping
from keras import Model
import rasterio
import earthpy.plot as ep
from keras.utils import to_categorical, plot_model, model_to_dot
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import from_levels_and_colors

# %%
FEATURES = ['B1', 'B2', 'B3', 'B4', 'B8', 'B11', 'B12', 'EVI', 'NBR', 'NDMI', 'NDWI', 'NDBI', 'NDBaI', 'elevation']
LABEL = ['classvalue']
SPLIT = ['sample']
N_CLASSES = 6
CLASSES = [1, 2, 3, 4, 5, 6]
PALETTE = ['#F08080', '#98FF00', '#228B22', '#FFC82D', '#A15622', '#000000']
SAMPLE_PATH = '../Conv1D_LULC_Classification/lc_gabung.csv'
#IMAGE_PATH = '../Conv1D_LULC_Classification/Sentinel_Pidie_Agustus_2024.tif'

# %%
image = rasterio.open(IMAGE_PATH)
bandNum = image.count
height = image.height
width = image.width
crs = image.crs
transform = image.transform
shape = (height, width)

image_vis = []
for x in [1,2,3]:
  image_vis.append(image.read(x))
image_vis = np.stack(image_vis)

plot_size = (8, 8)
ep.plot_rgb(
  image_vis,
  figsize=plot_size,
  stretch=True,
)
# Out:
# <Axes: >

# %%
samples = pd.read_csv(SAMPLE_PATH)
samples = samples.sample(frac = 1) # Shuffle data
samples
# Out:
#             B1       B2       B3       B4       B8      B11      B12  \
# 5891   0.24550  0.22065  0.23965  0.21540  0.42760  0.29895  0.23525
# 23691  0.52980  0.50770  0.48040  0.45880  0.53980  0.44090  0.36840
# 9700   0.29625  0.27250  0.27710  0.25725  0.42495  0.29590  0.22350
# 9339   0.33655  0.38595  0.37535  0.36140  0.47760  0.40835  0.29165
# 14364  0.16480  0.18440  0.20640  0.19200  0.28820  0.29180  0.21730
# ...        ...      ...      ...      ...      ...      ...      ...
# 487    0.22570  0.23105  0.24575  0.24360  0.29615  0.20210  0.17095
# 3704   0.13735  0.15100  0.18165  0.15980  0.45370  0.28095  0.19290
# 25198  0.15970  0.14520  0.18490  0.16460  0.46860  0.38500  0.26140
# 13207  0.21650  0.23370  0.26960  0.27710  0.45640  0.38910  0.31310
# 10170  0.43415  0.45195  0.42900  0.40125  0.52865  0.39825  0.33735
#
#             EVI       NBR      NDMI      NDWI      NDBI     NDBaI  elevation  \
# 5891   0.498064  0.290186  0.177070 -0.281679 -0.177070  0.119244         12
# 23691  0.417655  0.188725  0.100846 -0.058224 -0.100846  0.089584        494
# 9700   0.453390  0.310664  0.179025 -0.210598 -0.179025  0.139392         41
# 9339   0.386624  0.241729  0.078165 -0.119878 -0.078165  0.166714          9
# 14364  0.227488  0.140257 -0.006207 -0.165386  0.006207  0.146337         37
# ...         ...       ...       ...       ...       ...       ...        ...
# 487    0.128186  0.268037  0.188761 -0.093006 -0.188761  0.083501          4
# 3704   0.574023  0.403341  0.235146 -0.428189 -0.235146  0.185818        504
# 25198  0.555881  0.283836  0.097938 -0.434124 -0.097938  0.191213         12
# 13207  0.328088  0.186225  0.079598 -0.257300 -0.079598  0.108231        254
# 10170  0.582773  0.220901  0.140684 -0.104057 -0.140684  0.082790         79
#
#        classvalue sample
# 5891            5  train
# 23691           5  train
# 9700            5  train
# 9339            5  train
# 14364           2  train
# ...           ...    ...
# 487             1  train
# 3704            4  train
# 25198           5   test
# 13207           1  train
# 10170           5  train
#
# [26161 rows x 16 columns]

# %%
# Split into train and test based on column
train = samples[samples['sample'] == 'train']
test = samples[samples['sample'] == 'test']

# Split between features and label
train_features = train[FEATURES]
train_label = train[LABEL]
test_features = test[FEATURES]
test_label = test[LABEL]

# Function to reshape array input
def reshape_input(array):
  shape = array.shape
  return array.reshape(shape[0], shape[1], 1)

# Convert samples dataframe (pandas) to numpy array
train_input = reshape_input(train_features.to_numpy())
test_input = reshape_input(test_features.to_numpy())

# Also make label data to categorical
train_output = to_categorical(train_label.to_numpy(), N_CLASSES + 1)
test_output = to_categorical(test_label.to_numpy(), N_CLASSES + 1)

# Show the data shape
print(f'Train features: {train_input.shape}\nTest features: {test_input.shape}\nTrain label: {train_output.shape}\nTest label: {test_output.shape}')
# Out:
# Train features: (20962, 14, 1)
# Test features: (5199, 14, 1)
# Train label: (20962, 7)
# Test label: (5199, 7)

# %%
# Make model for our data
# Input shape
train_shape = train_input.shape
input_shape = (train_shape[1], train_shape[2])

# Model parameter
neuron = 64
drop = 0.1
kernel = 2
pool = 2

# Make sequential model
model = Sequential([
  Input(input_shape),
  Conv1D(neuron * 1, kernel , activation='relu'),
  Conv1D(neuron * 1, kernel, activation='relu'),
  MaxPooling1D(pool,pool),
  Dropout(drop),
  Conv1D(neuron * 2, kernel, activation='relu'),
  Conv1D(neuron * 2, kernel, activation='relu'),
  MaxPooling1D(pool,pool),
  Dropout(drop),
  GlobalMaxPooling1D(),
  Dense(neuron * 2, activation='relu'),
  Dropout(drop),
  Dense(neuron * 1, activation='relu'),
  Dropout(drop),
  Dense(N_CLASSES + 1, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 13, 64)            192
#
#  conv1d_1 (Conv1D)           (None, 12, 64)            8256
#
#  max_pooling1d (MaxPooling1D  (None, 6, 64)            0
#  )
#
#  dropout (Dropout)           (None, 6, 64)             0
#
#  conv1d_2 (Conv1D)           (None, 5, 128)            16512
#
#  conv1d_3 (Conv1D)           (None, 4, 128)            32896
#
#  max_pooling1d_1 (MaxPooling  (None, 2, 128)           0
#  1D)
#
#  dropout_1 (Dropout)         (None, 2, 128)            0
#
#  global_max_pooling1d (Globa  (None, 128)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 83,079
# Trainable params: 83,079
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model

# Compline the model
model.compile(
    optimizer='Adam',
    loss='CategoricalCrossentropy',
    metrics=['accuracy']
)

# Create callback to stop training if loss not decreasing
stop = EarlyStopping(
    monitor='loss',
    patience=50
)

# Fit the model
result = model.fit(
    x=train_input, y=train_output,
    validation_data=(test_input, test_output),
    batch_size=1024,
    callbacks=[stop],
    epochs=100,
)
# Out:
# Epoch 1/100
# 21/21 [==============================] - 2s 43ms/step - loss: 1.8706 - accuracy: 0.5048 - val_loss: 1.3074 - val_accuracy: 0.6242
# Epoch 2/100
# 21/21 [==============================] - 1s 37ms/step - loss: 1.2661 - accuracy: 0.6000 - val_loss: 1.1694 - val_accuracy: 0.6190
# Epoch 3/100
# 21/21 [==============================] - 1s 41ms/step - loss: 1.2056 - accuracy: 0.6007 - val_loss: 1.1295 - val_accuracy: 0.6244
# Epoch 4/100
# 21/21 [==============================] - 1s 39ms/step - loss: 1.1689 - accuracy: 0.6010 - val_loss: 1.0765 - val_accuracy: 0.6394
# Epoch 5/100
# 21/21 [==============================] - 1s 38ms/step - loss: 1.1035 - accuracy: 0.6074 - val_loss: 0.9898 - val_accuracy: 0.6324
# Epoch 6/100
# 21/21 [==============================] - 1s 38ms/step - loss: 1.0087 - accuracy: 0.6470 - val_loss: 0.8990 - val_accuracy: 0.7011
# Epoch 7/100
# 21/21 [==============================] - 1s 38ms/step - loss: 0.9363 - accuracy: 0.6900 - val_loss: 0.8473 - val_accuracy: 0.7359
# Epoch 8/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.8747 - accuracy: 0.7163 - val_loss: 0.7861 - val_accuracy: 0.7759
# Epoch 9/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.8184 - accuracy: 0.7346 - val_loss: 0.7559 - val_accuracy: 0.7773
# Epoch 10/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.7730 - accuracy: 0.7469 - val_loss: 0.7157 - val_accuracy: 0.8013
# Epoch 11/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.7399 - accuracy: 0.7586 - val_loss: 0.7001 - val_accuracy: 0.7978
# Epoch 12/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.7172 - accuracy: 0.7660 - val_loss: 0.6759 - val_accuracy: 0.8080
# Epoch 13/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.6961 - accuracy: 0.7732 - val_loss: 0.6634 - val_accuracy: 0.8055
# Epoch 14/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.6711 - accuracy: 0.7809 - val_loss: 0.6360 - val_accuracy: 0.8117
# Epoch 15/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.6510 - accuracy: 0.7880 - val_loss: 0.6199 - val_accuracy: 0.8215
# Epoch 16/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.6396 - accuracy: 0.7951 - val_loss: 0.6194 - val_accuracy: 0.8265
# Epoch 17/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.6246 - accuracy: 0.8000 - val_loss: 0.6091 - val_accuracy: 0.8311
# Epoch 18/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.6077 - accuracy: 0.8064 - val_loss: 0.5948 - val_accuracy: 0.8332
# Epoch 19/100
# 21/21 [==============================] - 1s 38ms/step - loss: 0.6001 - accuracy: 0.8064 - val_loss: 0.5971 - val_accuracy: 0.8257
# Epoch 20/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.5956 - accuracy: 0.8085 - val_loss: 0.6066 - val_accuracy: 0.8217
# Epoch 21/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.5848 - accuracy: 0.8115 - val_loss: 0.5909 - val_accuracy: 0.8313
# Epoch 22/100
# 21/21 [==============================] - 1s 46ms/step - loss: 0.5726 - accuracy: 0.8147 - val_loss: 0.5920 - val_accuracy: 0.8313
# Epoch 23/100
# 21/21 [==============================] - 1s 48ms/step - loss: 0.5715 - accuracy: 0.8168 - val_loss: 0.5857 - val_accuracy: 0.8280
# Epoch 24/100
# 21/21 [==============================] - 1s 46ms/step - loss: 0.5626 - accuracy: 0.8182 - val_loss: 0.5998 - val_accuracy: 0.8261
# Epoch 25/100
# 21/21 [==============================] - 1s 47ms/step - loss: 0.5575 - accuracy: 0.8215 - val_loss: 0.5698 - val_accuracy: 0.8398
# Epoch 26/100
# 21/21 [==============================] - 1s 46ms/step - loss: 0.5503 - accuracy: 0.8221 - val_loss: 0.5827 - val_accuracy: 0.8336
# Epoch 27/100
# 21/21 [==============================] - 1s 47ms/step - loss: 0.5465 - accuracy: 0.8225 - val_loss: 0.5870 - val_accuracy: 0.8323
# Epoch 28/100
# 21/21 [==============================] - 1s 46ms/step - loss: 0.5443 - accuracy: 0.8214 - val_loss: 0.5897 - val_accuracy: 0.8227
# Epoch 29/100
# 21/21 [==============================] - 1s 45ms/step - loss: 0.5476 - accuracy: 0.8218 - val_loss: 0.5928 - val_accuracy: 0.8336
# Epoch 30/100
# 21/21 [==============================] - 1s 45ms/step - loss: 0.5382 - accuracy: 0.8260 - val_loss: 0.5666 - val_accuracy: 0.8346
# Epoch 31/100
# 21/21 [==============================] - 1s 57ms/step - loss: 0.5334 - accuracy: 0.8258 - val_loss: 0.5705 - val_accuracy: 0.8396
# Epoch 32/100
# 21/21 [==============================] - 1s 67ms/step - loss: 0.5285 - accuracy: 0.8272 - val_loss: 0.5782 - val_accuracy: 0.8286
# Epoch 33/100
# 21/21 [==============================] - 1s 67ms/step - loss: 0.5251 - accuracy: 0.8284 - val_loss: 0.5662 - val_accuracy: 0.8423
# Epoch 34/100
# 21/21 [==============================] - 1s 66ms/step - loss: 0.5204 - accuracy: 0.8282 - val_loss: 0.5697 - val_accuracy: 0.8359
# Epoch 35/100
# 21/21 [==============================] - 1s 60ms/step - loss: 0.5160 - accuracy: 0.8307 - val_loss: 0.5670 - val_accuracy: 0.8423
# Epoch 36/100
# 21/21 [==============================] - 1s 61ms/step - loss: 0.5150 - accuracy: 0.8329 - val_loss: 0.5662 - val_accuracy: 0.8444
# Epoch 37/100
# 21/21 [==============================] - 1s 60ms/step - loss: 0.5099 - accuracy: 0.8324 - val_loss: 0.5658 - val_accuracy: 0.8438
# Epoch 38/100
# 21/21 [==============================] - 1s 60ms/step - loss: 0.5098 - accuracy: 0.8326 - val_loss: 0.5695 - val_accuracy: 0.8394
# Epoch 39/100
# 21/21 [==============================] - 1s 63ms/step - loss: 0.5019 - accuracy: 0.8344 - val_loss: 0.5598 - val_accuracy: 0.8440
# Epoch 40/100
# 21/21 [==============================] - 1s 57ms/step - loss: 0.4995 - accuracy: 0.8376 - val_loss: 0.5564 - val_accuracy: 0.8434
# Epoch 41/100
# 21/21 [==============================] - 1s 60ms/step - loss: 0.5033 - accuracy: 0.8337 - val_loss: 0.5756 - val_accuracy: 0.8415
# Epoch 42/100
# 21/21 [==============================] - 1s 60ms/step - loss: 0.5021 - accuracy: 0.8338 - val_loss: 0.5537 - val_accuracy: 0.8455
# Epoch 43/100
# 21/21 [==============================] - 1s 58ms/step - loss: 0.4989 - accuracy: 0.8374 - val_loss: 0.5775 - val_accuracy: 0.8346
# Epoch 44/100
# 21/21 [==============================] - 1s 61ms/step - loss: 0.4977 - accuracy: 0.8366 - val_loss: 0.5563 - val_accuracy: 0.8465
# Epoch 45/100
# 21/21 [==============================] - 1s 60ms/step - loss: 0.4890 - accuracy: 0.8393 - val_loss: 0.5616 - val_accuracy: 0.8457
# Epoch 46/100
# 21/21 [==============================] - 1s 60ms/step - loss: 0.4827 - accuracy: 0.8407 - val_loss: 0.5576 - val_accuracy: 0.8469
# Epoch 47/100
# 21/21 [==============================] - 1s 59ms/step - loss: 0.4794 - accuracy: 0.8409 - val_loss: 0.5714 - val_accuracy: 0.8461
# Epoch 48/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.4779 - accuracy: 0.8409 - val_loss: 0.5626 - val_accuracy: 0.8494
# Epoch 49/100
# 21/21 [==============================] - 1s 59ms/step - loss: 0.4772 - accuracy: 0.8402 - val_loss: 0.5528 - val_accuracy: 0.8492
# Epoch 50/100
# 21/21 [==============================] - 1s 59ms/step - loss: 0.4749 - accuracy: 0.8413 - val_loss: 0.5542 - val_accuracy: 0.8523
# Epoch 51/100
# 21/21 [==============================] - 1s 57ms/step - loss: 0.4709 - accuracy: 0.8425 - val_loss: 0.5566 - val_accuracy: 0.8544
# Epoch 52/100
# 21/21 [==============================] - 1s 59ms/step - loss: 0.4663 - accuracy: 0.8456 - val_loss: 0.5675 - val_accuracy: 0.8480
# Epoch 53/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.4668 - accuracy: 0.8449 - val_loss: 0.5651 - val_accuracy: 0.8534
# Epoch 54/100
# 21/21 [==============================] - 1s 58ms/step - loss: 0.4642 - accuracy: 0.8482 - val_loss: 0.5693 - val_accuracy: 0.8434
# Epoch 55/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.4674 - accuracy: 0.8451 - val_loss: 0.5600 - val_accuracy: 0.8544
# Epoch 56/100
# 21/21 [==============================] - 1s 55ms/step - loss: 0.4575 - accuracy: 0.8476 - val_loss: 0.5583 - val_accuracy: 0.8488
# Epoch 57/100
# 21/21 [==============================] - 1s 59ms/step - loss: 0.4636 - accuracy: 0.8446 - val_loss: 0.5395 - val_accuracy: 0.8525
# Epoch 58/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.4610 - accuracy: 0.8476 - val_loss: 0.5370 - val_accuracy: 0.8588
# Epoch 59/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.4544 - accuracy: 0.8478 - val_loss: 0.5379 - val_accuracy: 0.8571
# Epoch 60/100
# 21/21 [==============================] - 1s 57ms/step - loss: 0.4477 - accuracy: 0.8488 - val_loss: 0.5566 - val_accuracy: 0.8496
# Epoch 61/100
# 21/21 [==============================] - 1s 57ms/step - loss: 0.4483 - accuracy: 0.8501 - val_loss: 0.5372 - val_accuracy: 0.8615
# Epoch 62/100
# 21/21 [==============================] - 1s 57ms/step - loss: 0.4480 - accuracy: 0.8498 - val_loss: 0.5478 - val_accuracy: 0.8521
# Epoch 63/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.4431 - accuracy: 0.8517 - val_loss: 0.5528 - val_accuracy: 0.8596
# Epoch 64/100
# 21/21 [==============================] - 1s 59ms/step - loss: 0.4409 - accuracy: 0.8527 - val_loss: 0.5231 - val_accuracy: 0.8615
# Epoch 65/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.4442 - accuracy: 0.8516 - val_loss: 0.5377 - val_accuracy: 0.8584
# Epoch 66/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.4392 - accuracy: 0.8541 - val_loss: 0.5259 - val_accuracy: 0.8563
# Epoch 67/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.4313 - accuracy: 0.8545 - val_loss: 0.5441 - val_accuracy: 0.8484
# Epoch 68/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.4351 - accuracy: 0.8564 - val_loss: 0.5421 - val_accuracy: 0.8492
# Epoch 69/100
# 21/21 [==============================] - 1s 59ms/step - loss: 0.4369 - accuracy: 0.8532 - val_loss: 0.5313 - val_accuracy: 0.8525
# Epoch 70/100
# 21/21 [==============================] - 1s 54ms/step - loss: 0.4286 - accuracy: 0.8573 - val_loss: 0.5333 - val_accuracy: 0.8567
# Epoch 71/100
# 21/21 [==============================] - 1s 58ms/step - loss: 0.4235 - accuracy: 0.8573 - val_loss: 0.5139 - val_accuracy: 0.8592
# Epoch 72/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.4247 - accuracy: 0.8586 - val_loss: 0.5128 - val_accuracy: 0.8609
# Epoch 73/100
# 21/21 [==============================] - 1s 55ms/step - loss: 0.4204 - accuracy: 0.8582 - val_loss: 0.5188 - val_accuracy: 0.8613
# Epoch 74/100
# 21/21 [==============================] - 1s 58ms/step - loss: 0.4272 - accuracy: 0.8574 - val_loss: 0.5227 - val_accuracy: 0.8565
# Epoch 75/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.4231 - accuracy: 0.8595 - val_loss: 0.5257 - val_accuracy: 0.8550
# Epoch 76/100
# 21/21 [==============================] - 1s 57ms/step - loss: 0.4172 - accuracy: 0.8594 - val_loss: 0.5354 - val_accuracy: 0.8538
# Epoch 77/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.4150 - accuracy: 0.8622 - val_loss: 0.5340 - val_accuracy: 0.8502
# Epoch 78/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.4111 - accuracy: 0.8631 - val_loss: 0.5217 - val_accuracy: 0.8538
# Epoch 79/100
# 21/21 [==============================] - 1s 57ms/step - loss: 0.4105 - accuracy: 0.8620 - val_loss: 0.5296 - val_accuracy: 0.8552
# Epoch 80/100
# 21/21 [==============================] - 1s 55ms/step - loss: 0.4121 - accuracy: 0.8624 - val_loss: 0.5378 - val_accuracy: 0.8515
# Epoch 81/100
# 21/21 [==============================] - 1s 59ms/step - loss: 0.4050 - accuracy: 0.8645 - val_loss: 0.5159 - val_accuracy: 0.8623
# Epoch 82/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.4015 - accuracy: 0.8654 - val_loss: 0.5171 - val_accuracy: 0.8656
# Epoch 83/100
# 21/21 [==============================] - 1s 57ms/step - loss: 0.3992 - accuracy: 0.8664 - val_loss: 0.5257 - val_accuracy: 0.8602
# Epoch 84/100
# 21/21 [==============================] - 1s 58ms/step - loss: 0.4047 - accuracy: 0.8642 - val_loss: 0.5279 - val_accuracy: 0.8588
# Epoch 85/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.3971 - accuracy: 0.8664 - val_loss: 0.5102 - val_accuracy: 0.8646
# Epoch 86/100
# 21/21 [==============================] - 1s 59ms/step - loss: 0.3929 - accuracy: 0.8690 - val_loss: 0.5144 - val_accuracy: 0.8661
# Epoch 87/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.4033 - accuracy: 0.8660 - val_loss: 0.5150 - val_accuracy: 0.8656
# Epoch 88/100
# 21/21 [==============================] - 1s 58ms/step - loss: 0.3963 - accuracy: 0.8651 - val_loss: 0.5203 - val_accuracy: 0.8686
# Epoch 89/100
# 21/21 [==============================] - 1s 58ms/step - loss: 0.3971 - accuracy: 0.8672 - val_loss: 0.5003 - val_accuracy: 0.8619
# Epoch 90/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.3966 - accuracy: 0.8659 - val_loss: 0.5045 - val_accuracy: 0.8586
# Epoch 91/100
# 21/21 [==============================] - 1s 59ms/step - loss: 0.3893 - accuracy: 0.8699 - val_loss: 0.5184 - val_accuracy: 0.8634
# Epoch 92/100
# 21/21 [==============================] - 1s 56ms/step - loss: 0.3891 - accuracy: 0.8698 - val_loss: 0.5195 - val_accuracy: 0.8544
# Epoch 93/100
# 21/21 [==============================] - 1s 58ms/step - loss: 0.3891 - accuracy: 0.8693 - val_loss: 0.5136 - val_accuracy: 0.8644
# Epoch 94/100
# 21/21 [==============================] - 1s 58ms/step - loss: 0.3905 - accuracy: 0.8696 - val_loss: 0.5114 - val_accuracy: 0.8650
# Epoch 95/100
# 21/21 [==============================] - 1s 57ms/step - loss: 0.3912 - accuracy: 0.8684 - val_loss: 0.5066 - val_accuracy: 0.8617
# Epoch 96/100
# 21/21 [==============================] - 1s 59ms/step - loss: 0.3833 - accuracy: 0.8730 - val_loss: 0.5154 - val_accuracy: 0.8563
# Epoch 97/100
# 21/21 [==============================] - 1s 58ms/step - loss: 0.3858 - accuracy: 0.8696 - val_loss: 0.4967 - val_accuracy: 0.8609
# Epoch 98/100
# 21/21 [==============================] - 1s 58ms/step - loss: 0.3766 - accuracy: 0.8724 - val_loss: 0.4931 - val_accuracy: 0.8690
# Epoch 99/100
# 21/21 [==============================] - 1s 58ms/step - loss: 0.3778 - accuracy: 0.8730 - val_loss: 0.5046 - val_accuracy: 0.8621
# Epoch 100/100
# 21/21 [==============================] - 1s 58ms/step - loss: 0.3723 - accuracy: 0.8740 - val_loss: 0.5029 - val_accuracy: 0.8632

# %%
history = pd.DataFrame(result.history)

plt.figure(figsize = (10, 8))
plt.plot(range(len(history['accuracy'].values.tolist())), history['accuracy'].values.tolist(), label = 'Train_Accuracy')
plt.plot(range(len(history['loss'].values.tolist())), history['loss'].values.tolist(), label = 'Train_Loss')
plt.plot(range(len(history['val_accuracy'].values.tolist())), history['val_accuracy'].values.tolist(), label = 'Test_Accuracy')
plt.plot(range(len(history['val_loss'].values.tolist())), history['val_loss'].values.tolist(), label = 'Test_Loss')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
prediction = np.argmax(model.predict(train_input), 1).flatten()
label = np.argmax(train_output, 1).flatten()

# Confusion matrix
cm = confusion_matrix(label, prediction, normalize='true')
cm = ConfusionMatrixDisplay(cm)
cm.plot()

# Classification report
print(classification_report(label, prediction))
# Out:
# 656/656 [==============================] - 1s 891us/step
#               precision    recall  f1-score   support
#
#            1       0.85      0.69      0.76      2229
#            2       0.83      0.87      0.85      2571
#            3       0.81      0.84      0.83      1750
#            4       0.86      0.85      0.86      1123
#            5       0.93      0.97      0.95     12593
#            6       0.75      0.31      0.44       696
#
#     accuracy                           0.89     20962
#    macro avg       0.84      0.76      0.78     20962
# weighted avg       0.89      0.89      0.88     20962

# %%
# Predict test data
prediction = np.argmax(model.predict(test_input), 1).flatten()
label = np.argmax(test_output, 1).flatten()

# Confusion matrix
cm = confusion_matrix(label, prediction, normalize='true')
cm = ConfusionMatrixDisplay(cm)
cm.plot()

# Classification report
print(classification_report(label, prediction))
# Out:
# 163/163 [==============================] - 0s 810us/step
#               precision    recall  f1-score   support
#
#            1       0.90      0.73      0.80       560
#            2       0.86      0.86      0.86       524
#            3       0.76      0.69      0.73       413
#            4       0.63      0.80      0.71       269
#            5       0.90      0.96      0.93      3249
#            6       0.40      0.10      0.16       184
#
#     accuracy                           0.86      5199
#    macro avg       0.74      0.69      0.70      5199
# weighted avg       0.85      0.86      0.85      5199

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import cohen_kappa_score
import numpy as np

# %%
prediction = np.argmax(model.predict(test_input), 1).flatten()
label = np.argmax(test_output, 1).flatten()
cm1 = confusion_matrix(label, prediction, normalize='true')
num_classes = 5
sensitivity = []
specificities = []

# Hitung sensitivitas untuk setiap kelas
for i in range(num_classes):
    TP = cm1[i, i]
    FN = np.sum(cm1[i, :]) - TP  # Jumlah semua FN untuk kelas i
    sensitivity_1 = TP / (TP + FN)
    sensitivity.append(sensitivity_1)

total = 0
for num in sensitivity:
    total += num

print("Sensitivity : ", total/6)

for i in range(num_classes):
    TN = np.sum(cm1) - np.sum(cm1[i, :]) - np.sum(cm1[:, i]) + cm1[i, i]
    FP = np.sum(cm1[:, i]) - cm1[i, i]
    specificity_1 = TN / (TN + FP)
    specificities.append(specificity_1)

total = 0
for num in specificities:
    total += num

print("Specificity : ", total/6)

mcc= matthews_corrcoef(label, prediction)
print('Matthews corrcoef : ',mcc)
KIA=cohen_kappa_score(label, prediction)
print('Cohen Kappa Index : ',KIA)
# Out:
# 163/163 [==============================] - 0s 817us/step
# Sensitivity :  0.6730923859009396
# Specificity :  0.7723993969301223
# Matthews corrcoef :  0.7565233348626698
# Cohen Kappa Index :  0.7538749578526673

# %%
prediction = np.argmax(model.predict(train_input), 1).flatten()
label = np.argmax(train_output, 1).flatten()
cm1 = confusion_matrix(label, prediction, normalize='true')
num_classes = 6
sensitivity = []
specificities = []

# Hitung sensitivitas untuk setiap kelas
for i in range(num_classes):
    TP = cm1[i, i]
    FN = np.sum(cm1[i, :]) - TP  # Jumlah semua FN untuk kelas i
    sensitivity_1 = TP / (TP + FN)
    sensitivity.append(sensitivity_1)

total = 0
for num in sensitivity:
    total += num

print("Sensitivity : ", total/6)

for i in range(num_classes):
    TN = np.sum(cm1) - np.sum(cm1[i, :]) - np.sum(cm1[:, i]) + cm1[i, i]
    FP = np.sum(cm1[:, i]) - cm1[i, i]
    specificity_1 = TN / (TN + FP)
    specificities.append(specificity_1)

total = 0
for num in specificities:
    total += num

print("Specificity : ", total/6)

mcc= matthews_corrcoef(label, prediction)
print('Matthews corrcoef : ',mcc)
KIA=cohen_kappa_score(label, prediction)
print('Cohen Kappa Index : ',KIA)
# Out:
# 656/656 [==============================] - 1s 867us/step
# Sensitivity :  0.7561044120595577
# Specificity :  0.9512208824119116
# Matthews corrcoef :  0.8141360675475279
# Cohen Kappa Index :  0.8125545301408386

# %%
y_prob = model.predict(train_input)

# Hitung ROC curve dan AUC untuk setiap kelas
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(1, 7):
    fpr[i], tpr[i], _ = roc_curve(train_output[:, i], y_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve untuk setiap kelas
plt.figure(figsize=(8, 6))
colors = plt.cm.get_cmap('tab10', 7)

for i in range(1,7):
    plt.plot(fpr[i], tpr[i], color=colors(i),
             label=f'ROC curve (class {i}) (area = {roc_auc[i]:.2f})')

# Plot garis diagonal untuk referensi
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')

# Tambahkan label dan judul pada plot
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve One-vs-Rest Multiclass (1-6 Class)')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# 656/656 [==============================] - 1s 884us/step
# C:\Users\jabir\AppData\Local\Temp\ipykernel_10264\3372588128.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', 7)

# %%
y_prob = model.predict(test_input)

# Hitung ROC curve dan AUC untuk setiap kelas
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(1,7):
    fpr[i], tpr[i], _ = roc_curve(test_output[:, i], y_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve untuk setiap kelas
plt.figure(figsize=(8, 6))
colors = plt.cm.get_cmap('tab10', 8)

for i in range(1,7):
    plt.plot(fpr[i], tpr[i], color=colors(i),
             label=f'ROC curve (class {i}) (area = {roc_auc[i]:.2f})')

# Plot garis diagonal untuk referensi
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')

# Tambahkan label dan judul pada plot
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve One-vs-Rest Multiclass (1-6 Class)')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# 163/163 [==============================] - 0s 884us/step
# C:\Users\jabir\AppData\Local\Temp\ipykernel_10264\1792854876.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', 8)
